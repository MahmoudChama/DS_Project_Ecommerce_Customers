# %% [markdown]
# # E-Commerce Customers

# %% [markdown]
# ### Importing librairies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ecom = pd.read_csv('Ecommerce Customers.csv')

# %%
ecom.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 25.5+ KB

# %%
ecom.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
sns.pairplot(ecom)

# %%
sns.heatmap(ecom.corr(),annot=True)
# Out:
# <ipython-input-81-7dadb8f452f7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ecom.corr(),annot=True)
# <AxesSubplot:>

# %%
sns.jointplot(data=ecom, x='Length of Membership',y='Yearly Amount Spent')

# %%
sns.regplot(data= ecom ,x='Time on Website',y='Yearly Amount Spent')
# Out:
# <AxesSubplot:xlabel='Time on Website', ylabel='Yearly Amount Spent'>

# %%
sns.regplot(data= ecom ,x='Avg. Session Length',y='Yearly Amount Spent')
# Out:
# <AxesSubplot:xlabel='Avg. Session Length', ylabel='Yearly Amount Spent'>

# %%
sns.regplot(data= ecom ,x='Time on App',y='Yearly Amount Spent')
# Out:
# <AxesSubplot:xlabel='Time on App', ylabel='Yearly Amount Spent'>

# %%
y=ecom['Yearly Amount Spent']
y
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
#           ...
# 495    573.847438
# 496    529.049004
# 497    551.620146
# 498    456.469510
# 499    497.778642
# Name: Yearly Amount Spent, Length: 500, dtype: float64

# %%
x=ecom[['Avg. Session Length','Time on App',	'Time on Website',	'Length of Membership']]
x
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=42)

# %% [markdown]
# # Model building & training

# %% [markdown]
# #### Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([25.72425621, 38.59713548,  0.45914786, 61.67473243])

# %% [markdown]
# # y= m1*x1 + m2*x2+ m3*x3+ m4*x4+ b

# %% [markdown]
# # Model prediction

# %%
model.predict([[39,63,70,32]])
# Out:
# /lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4389.94364111])

# %%
y_pred= model.predict(x_test)
y_pred
# Out:
# array([403.66993074, 542.57756279, 427.06591624, 502.02460418,
#        410.12143558, 569.93442498, 531.93431357, 506.29651001,
#        408.71870637, 473.97737102, 441.46912713, 425.33703067,
#        425.12972304, 527.61676736, 431.45684042, 424.07691828,
#        575.76543275, 484.8985653 , 458.35936887, 481.96502194,
#        502.32441485, 513.63783571, 507.58877004, 646.57464281,
#        450.24372153, 496.27043414, 556.40457802, 554.95630854,
#        399.64237181, 325.84623149, 532.89783273, 478.12238679,
#        501.05701852, 305.9733584 , 505.77244465, 483.79591959,
#        518.83315284, 438.18241848, 456.71094212, 471.04609471,
#        494.44008982, 445.31155776, 508.78802753, 501.04594195,
#        488.83499651, 535.38079536, 595.20129815, 514.04714863,
#        280.76758287, 433.10112339, 421.70823429, 481.23640159,
#        584.71372254, 608.77480967, 563.98513435, 494.72804856,
#        394.52133409, 456.41975284, 573.08767517, 499.69842395,
# ...

# %%
y_test.values
# Out:
# array([401.0331352, 534.7771881, 418.6027421, 503.9783791, 410.0696111,
#        557.6082621, 538.9419745, 514.3365583, 408.6201878, 475.0154071,
#        427.1993849, 434.0216998, 411.1869636, 533.5149353, 447.3690272,
#        407.542168 , 573.8474377, 497.5866713, 466.4211988, 467.8009244,
#        510.4013885, 510.5014785, 511.97986  , 640.5840619, 444.2859075,
#        502.7710746, 551.6201455, 548.5185293, 390.103273 , 330.594446 ,
#        535.3216101, 478.6009159, 499.1401524, 298.7620079, 487.5475049,
#        498.6355985, 512.1658664, 444.9665517, 468.6684656, 483.1597208,
#        474.5323294, 439.0747667, 515.5024797, 485.9231305, 491.0732237,
#        544.7798637, 587.951054 , 522.3374046, 275.9184207, 436.5156057,
#        418.1500811, 493.719193 , 573.3062223, 608.2718166, 545.9454921,
#        483.673308 , 424.1854943, 452.3156755, 568.7175759, 488.7860611,
#        510.6617922, 376.4968407, 473.3604956, 479.2474168, 475.7590678,
# ...

# %% [markdown]
# # Model Evaluation

# %%
model.score(x, y)
# Out:
# 0.9842821675283161

# %%
from sklearn.metrics import mean_absolute_error

# %%
print(mean_absolute_error(y_test,y_pred))
# Out:
# 8.426091635451506

# %% [markdown]
# # Coeffiencients

# %%
model.coef_
# Out:
# array([25.72425621, 38.59713548,  0.45914786, 61.67473243])

# %% [markdown]
# ### y (yearly Ammount spent) = 25.72425621 *x1(average) + 38.59713548*x2(app) + 0.45914786 *x3(website) +  61.67473243* x4 (Membership) +b

# %% [markdown]
# # Thank you
